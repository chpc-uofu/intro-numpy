# %% [markdown]
# # Hands-On Introduction to NumPy and SciPy

# %% [markdown]
# ## Content
# - [Motivation](why.ipynb)
# - [Lecture 1](lec1.ipynb)
#   * Creation of NumPy arrays
# - [Lecture 2](lec2.ipynb)
#   * Array attributes ($\texttt{dtype,ndim,shape,size,flags,T}$)
#   * Creation of specific arrays ($\texttt{dtypes, diag, ones, zeros, eye,..}$)
#   * Creation of random arrays
# - [Lecture 3](lec3.ipynb)
#   * Indexing & slicing
# - [Lecture 4](lec4.ipynb)
#   * Vector operations
#   * Matrix multiplication
#   * Broadcasting
# - [Lecture 5](lec5.ipynb)
#   * Universal functions
# - [Lecture 6](lec6.ipynb)
#   * Fancy indexing
# - [Lecture 7](lec7.ipynb)
#   * Concatenation & splitting of ndarrays
#   * Constants in NumPy
# - [Lecture 8](lec8.ipynb)
#   * Linear Algebra in NumPy & SciPy
#   * FFT
#   * Random number generators & probability distributions
# - [Lecture 9](lec9.ipynb)
#   * IO in NumPy
# - [Lecture 10](lec10.ipynb)
#   * Special functions in SciPy
#   * Numerical integration in SciPy
#   * Optimization in SciPy
#   * Interpolation in SciPy
